# %%
# Test Notebook for Anaconda Environment

# Import required libraries
import IPython
import ipywidgets
import jupyter
import kaleido
import matplotlib
import numpy
import cv2
import pandas
import plotly
import readlif
import scipy
import seaborn
import skimage
import statsmodels
import tsfresh
import utils
import ipympl
import openpyxl

# Print versions
print(f"ipython: {IPython.__version__}")
print(f"ipywidgets: {ipywidgets.__version__}")
print(f"jupyter: {jupyter.__version__}")
print(f"kaleido: {kaleido.__version__}")
print(f"matplotlib: {matplotlib.__version__}")
print(f"numpy: {numpy.__version__}")
print(f"opencv-python: {cv2.__version__}")
print(f"pandas: {pandas.__version__}")
print(f"plotly: {plotly.__version__}")
print(f"readlif: {readlif.__version__}")
print(f"ruptures: {ruptures.__version__}")
print(f"scipy: {scipy.__version__}")
print(f"seaborn: {seaborn.__version__}")
print(f"scikit-image: {skimage.__version__}")
print(f"statsmodels: {statsmodels.__version__}")
print(f"tsfresh: {tsfresh.__version__}")
print(f"ipympl: {ipympl.__version__}")
print(f"openpyxl: {openpyxl.__version__}")

print("Done! Environment successfully created and activated!")
