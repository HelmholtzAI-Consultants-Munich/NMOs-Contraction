# %% [markdown]
# # Time series analysis
# ---
#
# Running this notebook you will:
#
# - Plot the timeseries
# - Extract the features
# - Plot the univarialte and bivariate relation between the features

# %%
#@markdown ###Run this cell to connect your Google Drive to Colab and install packages

#@markdown After the first execution you might receive some warning and notifications, please follow these instructions:

#@markdown * Warning: This notebook was not authored by Google. Click on *'Run anyway'*.
#@markdown * Permit this notebook to access your Google Drive files? Click on *'Yes'*, and select your account.
#@markdown * Google Drive for desktop wants to access your Google Account. Click on *'Allow'*.

# Mounts user's Google Drive to Google Colab switch folder.
from google.colab import drive
drive.mount('/content/gdrive')
#%cd /content/gdrive/MyDrive/
#!git clone https://github.com/HelmholtzAI-Consultants-Munich/NMOs-Contraction.git
# %cd /content/gdrive/MyDrive/NMO-colab/

# Install necessary packages
# %pip install tsfresh
# %pip install -U kaleido
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/NMO-colab
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tsfresh
#   Downloading tsfresh-0.20.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (0.13.5)
# Requirement already satisfied: numpy>=1.15.1 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (1.22.4)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (2.27.1)
# Requirement already satisfied: dask[dataframe]>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (2022.12.1)
# Requirement already satisfied: distributed>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (2022.12.1)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (0.5.3)
# Collecting stumpy>=1.7.2
#   Downloading stumpy-1.11.1-py3-none-any.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.2/136.2 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (1.2.2)
# Requirement already satisfied: tqdm>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (4.65.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from tsfresh) (2.2.1)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.9.0->tsfresh) (0.12.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.9.0->tsfresh) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.9.0->tsfresh) (23.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.9.0->tsfresh) (8.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.9.0->tsfresh) (2023.4.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.9.0->tsfresh) (1.4.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh) (1.26.15)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh) (6.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh) (3.1.2)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh) (1.0.5)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh) (1.0.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh) (5.9.5)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh) (3.0.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh) (1.7.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.11.0->tsfresh) (2.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->tsfresh) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->tsfresh) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.4.1->tsfresh) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->tsfresh) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->tsfresh) (1.2.0)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.10/dist-packages (from stumpy>=1.7.2->tsfresh) (0.56.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.54->stumpy>=1.7.2->tsfresh) (67.7.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.54->stumpy>=1.7.2->tsfresh) (0.39.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->distributed>=2.11.0->tsfresh) (2.1.2)
# Installing collected packages: stumpy, tsfresh
# Successfully installed stumpy-1.11.1 tsfresh-0.20.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.1 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
#@markdown ## Import
#@markdown Run the next cell to import the necessary packages

import glob
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import kaleido
from IPython.display import Markdown as md
import ipywidgets as widgets

from utils.pre_processing import process_single_ts
from utils.feature_extraction import create_feature_in_dataframe
from utils.plot_boxplot import plot_box_plots

# %%
#@markdown ## Custom data path

#@markdown In case you will change the folder structure, you can insert here the paths to the data (extracted time series) and the figures.

data_path = 'extracted_signals' #@param {type:"string"}
figure_path = 'figures' #@param {type:"string"}
figure_path = figure_path + '/'

# %%
#@markdown ## Pre-processing
#@markdown Running this cell the you will open the time series and the info file data, and pre-process the time series.

#@markdown The pre-processing consist of the following steps:
#@markdown - polynomial interpolation in case missing values are present
#@markdown - de-trending
#@markdown - smoothing
#@markdown - scaling: pixel in micrometer and bin in seconds

#@markdown  If you want to print the complete list of all the processed data check the box below.

# Open data info file
data_info = pd.read_excel('Contraction_videos_legend.xlsx')
# Rename columns and fill NA values
data_info.rename(columns={'File_video name': 'Filename'}, inplace=True)
data_info['Treatment during contraction'].fillna('Other', inplace=True)

# Open time series files
filename_list = []
data = []
files = []

for filename in glob.glob(os.path.join(data_path, '*.npy')):
    filename_list.append(Path(filename).stem)
    with open(filename, 'r') as f:
        data.append([Path(filename).stem, np.load(filename)])

print_filenames = False #@param {type:"boolean"}
if print_filenames:
  for index, name in enumerate(filename_list):
     print(index, name)     

# Delete tail corrupted data
if 'O1318_1b' in filename_list:
  element = 'O1318_1b'
  print(f'The tale of {element} has been cut beacuse the data were currupted.')
  index = filename_list.index(element)
  data[index][1] = data[index][1][:, :650]

# Pre-processing
data_processed = []

for data_i in data:
  data_processed_i, is_nan_flag = process_single_ts(data_i[1], smooth=True, de_trend=True)
  data_processed.append([data_i[0], data_processed_i])
  if is_nan_flag:
    print(f'The signal {data_i[0]} has NaNs and the missing values have been interpolated')

print(f'Number of processed files: {len(filename_list)}')
# Out:
# The tale of the file O1318_1b has been cut beacuse the data were currupted.
# The signal O4979_1a has NaNs and the missing values have been interpolated
# Number of processed files: 68

# %%
#@markdown ## Plot all time series
#@markdown Run this cell to visualize all the time series after the pre-processing step
#@markdown The plots will be saved in the figure folder (in a unique file called 'All Time Series' and also in multiple small windows for a better visualization.

#@markdown Here you can choose where to set the value for the horizontal dashed line to help you visualizing the different time series

line_of_reference = 0.5 #@param {type:"number"}
t_weak = line_of_reference
t_conversion = 0.097
plot_info = {'y_min': -2.5,
             'y_max': 2.5,
             'subplot_layout_row': 34, 
             'subplot_layout_col': 2, 
             'title': 'All Time Series'}

colors = ["#43C6DB", "#93FFE8", "dodgerblue", "mediumseagreen", "slateblue", "#737CA1", "#29465B", "#368BC1",
          "#AFDCEC", "#66CDAA"]

fig, axis = plt.subplots(plot_info['subplot_layout_row'], plot_info['subplot_layout_col'], figsize=(20, 70))
fig.suptitle(plot_info['title'], fontsize=16)
plt.tight_layout(pad=3.)
for ax, data_i in zip(axis.flat, data_processed):
    for i in range(data_i[1].shape[0]):
        ax.plot([t * t_conversion for t in range(len(data_i[1][i, :]))], data_i[1][i, :], color=colors[i], alpha=0.5)
    ax.set_title(data_i[0], y=2., pad=-14)
    ax.set_xlabel('Time [s]')
    ax.set_ylabel('y [\u03BCm]')
    ax.set_ylim(plot_info['y_min'], plot_info['y_max'])
    ax.axhline(y=t_weak, color='g', linestyle='--', label='std')
    ax.axhline(y=-t_weak, color='g', linestyle='--', label='std')
fig.savefig(figure_path + plot_info['title'])
# plot_all_signals = True #@param {type:"boolean"}
# if plot_all_signals == False: 
#   plt.close()

# Save figures in different files 
plot_info = {'y_min': -2.5,
             'y_max': 2.5,
             'subplot_layout_row': 5,
             'subplot_layout_col': 2,
             'title': 'Time series - window '}
number_of_windows = 7
ind_start = 0
incr = plot_info['subplot_layout_row'] * plot_info['subplot_layout_col']
ind_stop = incr
for window_n in range(number_of_windows):
    fig, axis = plt.subplots(plot_info['subplot_layout_row'], plot_info['subplot_layout_col'], figsize=(15, 10))
    fig.suptitle(plot_info['title'] + str(window_n + 1), fontsize=16, y=0.98)
    plt.tight_layout(pad=3.)
    for ax, data_i in zip(axis.flat, data_processed[ind_start:ind_stop]):
        for i in range(data_i[1].shape[0]):
            ax.plot([t * t_conversion for t in range(len(data_i[1][i, :]))], data_i[1][i, :],
                    color=colors[i], alpha=0.5)
        ax.set_title(data_i[0], y=1.5, pad=-14)
        ax.set_xlabel('Time [s]')
        ax.set_ylabel('y [\u03BCm]')
        ax.set_ylim(plot_info['y_min'], plot_info['y_max'])
        ax.axhline(y=t_weak, color='g', linestyle='--', label='std')
        ax.axhline(y=-t_weak, color='g', linestyle='--', label='std')
    ind_start = ind_stop
    ind_stop += incr
    fig.savefig(figure_path + plot_info['title'] + str(window_n + 1))
    plt.close(fig)

# %%
#@markdown ### Plot a specific time series
t_conversion = 0.097
#@markdown If you want to focus only on specific signals and compare them, check the following box and enter the names of the signals you are interested in.
#@markdown You can visualize up to 4 signals at the same time, customize the rows and colums.

signal_1 = 'O4980_2a' #@param {type:"string"}
signal_2 = 'O1319_1a' #@param {type:"string"}
signal_3 = 'O1449_1a' #@param {type:"string"}
signal_4 = '' #@param {type:"string"}

rows = 4 #@param {type:"integer"}
columns = 2 #@param {type:"integer"}

plot_info = {'y_min': -2.5,
             'y_max': 2.5,
             'subplot_layout_row': 34, 
             'subplot_layout_col': 2, 
             'title': 'All Time Series'}
colors = ["#43C6DB", "#93FFE8", "dodgerblue", "mediumseagreen", "slateblue", "#737CA1", "#29465B", "#368BC1",
          "#AFDCEC", "#66CDAA"]
signal_list = [signal_1, signal_2, signal_3, signal_4]
signal_list_plot = [s for s in signal_list if s]
ind_list = [filename_list.index(s) for s in signal_list_plot]
data_processed_plot = [data_processed[ind] for ind in ind_list]
ind_plot = rows * columns
data_processed_plot = data_processed_plot[:(ind_plot)]

#@markdown If you want to save the figure, check the following box insert, and choose a name. 
#@markdown The figure in png and html formats will be saved in the 'figures' folder.
#@markdown (The html formal allows you to have an interactive figure. To open it you have to download it first, then double click on the file and a window with the figure will open in your browser).
save = False #@param {type:"boolean"}
plot_title = '' #@param {type:"string"}
fig_new = make_subplots(rows=rows, cols=columns, subplot_titles=signal_list)
r = 0
c = 0
for i in range(len(data_processed_plot)): #len(data_processed)):
  
  fig_ = px.line(x=[t * t_conversion for t in range(len(data_processed_plot[i][1][0]))], y=[data_i for data_i in data_processed_plot[i][1]], color_discrete_sequence=colors,
                  range_y=[plot_info['y_min'], plot_info['y_max']])
  fig_.update_layout(showlegend=False)
  fig_.update_traces(opacity=0.5)

  if columns == 1:
    c = 1
    r += 1
  elif rows == 1:
    r = 1
    c += 1
  else:
    if c == 2:
      if r == 0:
        r = 1
      r +=1
      c = 1
    else:
      if r == 0:
        r = 1
      c +=1

  for trace in fig_["data"]:
    fig_new.add_trace(trace, row=r, col=c)
    fig_new.update_xaxes(title_text='Time [s]', row=r, col=c)
    fig_new.update_yaxes(title_text='y [\u03BCm]', row=r, col=c, range=[plot_info['y_min'], plot_info['y_max']])
fig_new.update_layout(height=800, width=1500)
fig_new.update_layout(showlegend=False)

if save:
  if plot_title == '':
    print('Attention! If you want to save the figure, please choose a name, and execute the cell!')
  else:
    fig_new.write_html(figure_path + plot_title + ".html")
    fig_new.write_image(figure_path + plot_title + ".png", format='png')
fig_new.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="
,25.511,25.608,25.705000000000002,25.802,25.899,25.996000000000002,26.093,26.19,26.287,26.384,26.481,26.578,26.675,26.772000000000002,26.869,26.966,27.063000000000002,27.16,27.257,27.354,27.451,27.548000000000002,27.645,27.742,27.839000000000002,27.936,28.033,28.130000000000003,28.227,28.324,28.421,28.518,28.615000000000002,28.712,28.809,28.906000000000002,29.003,29.1,29.197,29.294,29.391000000000002,29.488,29.585,29.682000000000002,29.779,29.876,29.973000000000003,30.07,30.167,30.264,30.361,30.458000000000002,30.555,30.652,30.749000000000002,30.846,30.943,31.04,31.137,31.234,31.331,31.428,31.525000000000002,31.622,31.719,31.816000000000003,31.913,32.01,32.107,32.204,32.301,32.398,32.495,32.592,32.689,32.786,32.883,32.980000000000004,33.077,33.174,33.271,33.368,33.465,33.562,33.659,33.756,33.853,33.95,34.047000000000004,34.144,34.241,34.338,34.43 ...

# %%
#@markdown ## Create DataFrame with extracted features and data info
#@markdown Running this cell you will extract the features and create a table with all the data info and the extracted features.

#@markdown - Energy
#@markdown - Mean
#@markdown - Percentage of Count Above Threshold
#@markdown - Percentage of Absolute Sum of Changes
#@markdown - 75 Quantile
#@markdown - Standard Deviazion

#@markdown Here you can set the threshold for the feature *Percentage of Count Above Threshold*. The default value is 0.5.
threshold = 0.5 #@param 
# Feature extraction
df_data = create_feature_in_dataframe(data_processed, threshold)

# Before the merge, rename the files to eliminate the extension and match the filenames between the two dataframes
data_info['Filename'] = data_info['Filename'].apply(lambda x: os.path.splitext(os.path.basename(x))[0])
df_data_final = pd.merge(df_data, data_info, on='Filename')

df_data_final
# Out:
#            Filename       Energy      Mean  %_of_count_above_threshold  \
# 0          O1445_2a     0.494167  0.001553                    0.019344
# 1          O1319_1a    70.826850  0.025057                    0.299610
# 2          O1318_2a     1.313557  0.001413                    0.070792
# 3          O1464_1a   208.187278  0.035326                    0.437763
# 4          O1468_1b  1648.618763 -0.007170                    0.517241
# ..              ...          ...       ...                         ...
# 62     p1228_d50_2b     0.514297  0.000380                    0.016083
# 63         O4979_2c     1.395115 -0.001946                    0.099425
# 64         O4979_2b     0.514565  0.000107                    0.033088
# 65     p1228_d50_2a     0.569267 -0.001875                    0.029777
# 66  O4980_2c-curare     0.506616  0.001049                    0.014866
#
#     %_of_absolute_sum_of_changes  Quantile_75  Standard_deviation  \
# 0                       0.012509     0.091639            0.218823
# 1                       0.062016     0.623074            2.617394
# 2                       0.027876     0.224592            0.356947
# 3                       0.096431     1.503946            4.493569
# 4                       0.498456     7.451611           12.645776
# ..                           ...          ...                 ...
# 62                      0.007837     0.154671            0.222649
# 63                      0.012318     0.237232            0.364986
# 64                      0.007377     0.140999            0.220994
# 65                      0.006536     0.135267            0.229818
# 66                      0.009050     0.135236            0.221644
#
#     %_of_count_above_mean Experiment (plate)    Cell line Phenotype  \
# 0                0.542893               P426      SMAE1C4   Disease
# 1                0.469621               P427           H1   Control
# 2                0.491639               P426      SMAE1C4   Disease
# 3                0.519765               P482  SMAE1C4+DOX  Recovery
# 4                0.533221               P487  SMAE1C4+DOX  Recovery
# ..                    ...                ...          ...       ...
# 62               0.496019              P1228           H1   Control
# 63               0.512948              P1263     H1 (LDN)   Control
# 64               0.454284              P1263     H1 (LDN)   Control
# 65               0.485669              P1228           H1   Control
# 66               0.494885              P1264  H1 (LDN+VF)   Control
#
#    Treatment during contraction  Day USER User classification       Sent  \
# 0                          None   60  AGP      No contraction 2022-05-16
# 1                          None   60  AGP  Strong contraction 2022-05-10
# 2                          None   60  AGP    Weak contraction 2022-05-10
# 3                          None   50  AGP  Strong contraction 2022-05-10
# 4                          None   50  AGP  Strong contraction 2022-05-10
# ..                          ...  ...  ...                 ...        ...
# 62                        Other   50   CB                 NaN 2022-12-05
# 63                        Other   50   CB                 NaN 2022-12-05
# 64                        Other   50   CB                 NaN 2022-12-05
# 65                        Other   50   CB                 NaN 2022-12-05
# 66                       Curare   50   CB                 NaN 2022-12-05
#
#    Comments Threshold
# 0       NaN   default
# 1       NaN   default
# 2       NaN   default
# 3       NaN   default
# 4       NaN   default
# ..      ...       ...
# 62    O4882   default
# 63      NaN   default
# 64      NaN   default
# 65    O4882   default
# 66      NaN      0.69
#
# [67 rows x 18 columns]

# %% [markdown]
# ## Univariate analysis

# %%
#@markdown Choose the feature for the classification and plot the boxplot for the different variables.
fig_uni_variate = make_subplots(rows=2, cols=3)
ax_list = [[1, 1], [1, 2], [1, 3], [2, 1], [2, 2], [2, 3]]
ind = 0

x_boxplot = 'Treatment during contraction' #@param ['Treatment during contraction', 'Phenotype']

#@markdown The figure will be automatically saved in the 'figures' folder.

for ax, col in zip(ax_list, list(df_data_final.columns)[1:7]):
    fig_ = px.box(df_data_final, x=x_boxplot, y=col, color=x_boxplot)# , points="outliers") # Options: None, all, ouliers, suspectedoutliers")
    for trace in fig_["data"]:
        trace.legendgroup = trace.name
        fig_uni_variate.add_trace(trace, row=ax[0], col=ax[1])
        if ind != 0:
            fig_uni_variate.data[-1].showlegend = False

    if col == 'Energy':
        units = 'Normalized Energy [\u03BCm^2 / s]'
    elif col in ['Standard_deviation', 'Mean', 'Quantile_75']:
        units = col + ' [\u03BCm]'
    else:
        units = col
    fig_uni_variate.update_layout(height=800, width=1500)
    fig_uni_variate.update_xaxes(title_text=x_boxplot, row=ax[0], col=ax[1])
    fig_uni_variate.update_yaxes(title_text=units, row=ax[0], col=ax[1])
    ind += 1

fig_uni_variate.show()
fig_uni_variate.write_html(figure_path + "Univariate - " + x_boxplot +".html")
fig_uni_variate.write_image(figure_path + "Univariate - " + x_boxplot + ".png", format='png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8a74874f-408f-479c-8fa7-93c24f4bd0a5" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a74874f-408f-479c-8fa7-93c24f4bd0a5")) {                    Plotly.newPlot(                        "8a74874f-408f-479c-8fa7-93c24f4bd0a5",                        [{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Disease","marker":{"color":"#636efa"},"name":"Disease","notched":false,"offsetgroup":"Disease","orientation":"v","showlegend":true,"x":["Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease"],"x0":" ","xaxis":"x","y":[0.49416710589837054,1.3135574108721397,0.802573020752049,0.35938633897348615,0.13991439466937375,187.54729422238972,0.38286058233088827,64.62311553487355,0.10888701342483698,0.43354780188984565,3.537289152048809,0.19404420953690626,0.06573115883776671,0.44389080869707453,2.782979007560317,0.4712450870880195,5.482655939911412,127.15055986861847,0.2884147400786852,0.8906798477852751,0.4493507980662288],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Control","marker":{"color":"#EF553B"},"name":"Control","notched":false,"offsetgroup":"Control","orientation":"v","showlegend":true,"x":["Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control"],"x0":" ","xaxis":"x","y":[70.82685036723323,0.09104614474482575,0.5747182983931713,1120.184976359315,167.05335661831808,447.3194195269595,0.6052206829870767,0.1691645741485961,0.7850272920584803,0.17274838161400352,0.08146190554369742,195.4058178429213,0.44508759420549027,0.3962202062055764,8.378148450908213,85.09533032174144,116.22788319150652,0.3795672586136454,124.17821946207339,0.3403602472147672,0.3266192600863902,771.8045734801482,0.5601366282423987,62.98749790939421,0.1333000269994818,0.39259157387830523,229.9106637151932,0.6683933401586679,0.17836333844421942,1.0039838862013906,0.5090113277334488,0.8254208337574522,1.2800154476229966,0.5142972053123516,1.3951148739045838,0.5145648119614865,0.5692668507950748,0.5066163990511908],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Recovery","marker":{"color":"#00cc96"},"name":"Recovery","notched":false,"offsetgroup":"Recovery","orientation":"v","showlegend":true,"x":["Recovery","Recovery","Recovery","Recovery","Recovery","Recovery"],"x0":" ","xaxis":"x","y":[208.1872781611356,1648.6187629803085,2.281302771437711,10.13531583409291,6.569781298247429,1578.8955641966086],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Disease II","marker":{"color":"#ab63fa"},"name":"Disease II","notched":false,"offsetgroup":"Disease II","orientation":"v","showlegend":true,"x":["Disease II","Disease II"],"x0":" ","xaxis":"x","y":[0.6777122653998229,0.6462093438770018],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Mean=%{y}<extra></extra>","legendgroup":"Disease","marker":{"color":"#636efa"},"name":"Disease","notched":false,"offsetgroup":"Disease","orientation":"v","showlegend":false,"x":["Disease","Disease","Disease","Disease", ...

# %% [markdown]
# ## Bi-variate analysis

# %%
#@markdown Choose the colors for the different **treatments**
my_colors = {'blue': 'royalblue',
             'red': 'orangered',
             'orange': 'darkorange',
             'green': 'mediumseagreen',
             'pink': 'orchid'

}
color_Curare = 'red' #@param ['blue', 'red', 'orange', 'green', 'pink']
color_None = 'blue' #@param ['blue', 'red', 'orange', 'green', 'pink']
color_Other = 'blue' #@param ['blue', 'red', 'orange', 'green', 'pink']
 
#@markdown Choose the marker for the different **phenotypes**
marker_Disease = 'square' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_Recovery = 'cross' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_Control = 'circle' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_Disease_II = 'square-open' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_size = 6 #@param {type:"slider", min:1, max:10, step:1} 

#@markdown The figure will be automatically saved in the 'figures' folder.

var_plot = [
    ['Energy', '%_of_absolute_sum_of_changes', 1, 1],
    ['Energy', 'Quantile_75', 1, 2],
    ['%_of_count_above_threshold', '%_of_absolute_sum_of_changes', 1, 3],
    ['%_of_absolute_sum_of_changes', 'Quantile_75', 2, 1],
    ['%_of_absolute_sum_of_changes', 'Standard_deviation', 2, 2],
    ['Quantile_75', 'Standard_deviation', 2, 3]
]

fig_final = make_subplots(rows=2, cols=3)

ind = 0
for x, y, r, c in var_plot:
    
    fig_ = px.scatter(df_data_final, x=x, y=y,
                 color='Treatment during contraction',
                 color_discrete_map={'Curare': my_colors[color_Curare],
                                      'None': my_colors[color_None],
                                      'Other': my_colors[color_Other]
                                     },
                 symbol='Phenotype',
                 hover_name = 'Filename',
                 symbol_sequence = [marker_Disease, marker_Recovery, marker_Control, marker_Disease_II]
                 )
    fig_.update_traces(marker_size=marker_size)

    for trace in fig_["data"]:
        trace.legendgroup = trace.name
        fig_final.add_trace(trace, row=r, col=c)
        if ind != 0:
            fig_final.data[-1].showlegend = False
    fig_final.update_layout(height=800, width=1500)
    fig_final.update_xaxes(title_text=x, row=r, col=c)
    fig_final.update_yaxes(title_text=y, row=r, col=c)
    ind += 1

fig_final.write_html(figure_path + "Bivariate.html")
fig_final.write_image(figure_path + "Bivariate.png")
fig_final.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d3587688-e038-49e8-a4d0-4e0db0cfa8b8" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3587688-e038-49e8-a4d0-4e0db0cfa8b8")) {                    Plotly.newPlot(                        "d3587688-e038-49e8-a4d0-4e0db0cfa8b8",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Treatment during contraction=None<br>Phenotype=Disease<br>Energy=%{x}<br>%_of_absolute_sum_of_changes=%{y}<extra></extra>","hovertext":["O1445_2a","O1318_2a","O1443_1b","O1318_1b","O1463_1b","O1318_3a","O1449_1a","O1449_1b","O1301_3a","O1409_1b","P766_1b","P918_1b_recovery_curare","O1463_2b","O1450_1b","O1463_2a","O1449_2a","O1467_2a","O1465_1b","O1469_1a"],"legendgroup":"None, Disease","marker":{"color":"royalblue","size":6,"symbol":"square"},"mode":"markers","name":"None, Disease","orientation":"v","showlegend":true,"x":[0.49416710589837054,1.3135574108721397,0.802573020752049,0.35938633897348615,0.13991439466937375,187.54729422238972,0.38286058233088827,64.62311553487355,0.10888701342483698,0.43354780188984565,0.19404420953690626,0.06573115883776671,2.782979007560317,0.4712450870880195,5.482655939911412,127.15055986861847,0.2884147400786852,0.8906798477852751,0.4493507980662288],"xaxis":"x","y":[0.01250908250542587,0.027876233342838487,0.018005362322262766,0.016722782413960312,0.0079353096547564,0.11746151408764006,0.0130060735606237,0.0471646636555733,0.008405820862434663,0.013826179391708873,0.007585957045765808,0.004265708265420003,0.027731122117989962,0.011442673504633918,0.03453628612261331,0.0780285288082587,0.015662574421803275,0.01992064455711605,0.019994211127259166],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Treatment during contraction=None<br>Phenotype=Control<br>Energy=%{x}<br>%_of_absolute_sum_of_changes=%{y}<extra></extra>","hovertext":["O1319_1a","O1319_3a","O1319_2a","O1448_2a"],"legendgroup":"None, Control","marker":{"color":"royalblue","size":6,"symbol":"cross"},"mode":"markers","name":"None, Control","orientation":"v","showlegend":true,"x":[70.82685036723323,0.09104614474482575,167.05335661831808,0.1333000269994818],"xaxis":"x","y":[0.062015734850354845,0.009250655391854663,0.06722596076012313,0.015259049572331852],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Treatment during contraction=None<br>Phenotype=Recovery<br>Energy=%{x}<br>%_of_absolute_sum_of_changes=%{y}<extra></extra>","hovertext":["O1464_1a","O1468_1b","O1466_2a","O1464_2a","O1464_1b","O1468_1c"],"legendgroup":"None, Recovery","marker":{"color":"royalblue","size":6,"symbol":"circle"},"mode":"markers","name":"None, Recovery","orientation":"v","showlegend":true,"x":[208.1872781611356,1648.6187629803085,2.281302771437711,10.13531583409291,6.569781298247429,1578.8955641966086],"xaxis":"x","y":[0.09643089044340511,0.4984564784462764,0.035855628369915,0.032191232940719794,0.033318200931989395,0.3903050593557986],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Treatment during contraction=Other<br>Phenotype=Control<br>Energy=%{x}<br>%_of_absolute_sum_of_changes=%{y}<extra></extra>","hovertext":["p1229_d50_1a","O4979_1a","O4979_1b","O4979_1c","p1228_d50_1a","p1228_d50_1c","O4980_1b","p1229_d50_2c","p1229_d50_2b","O4980_1a","O4980_3c","O4980_3b","O4980_3a","O4980_2a","O4980_2b","p1229_d50_1c","p1229_d50_1b","O4980_2c","O4979_3b","O4979_3a","O4979_2a","p1228_d50_2b","O4979_2c","O4979_2b","p1228_d50_2a"],"legendgroup":"Other, Control","marker":{"color":"royalblue","size":6,"symbol":"cross"},"mode":"markers","name":"Other, Control","orientation":"v","showlegend":true,"x":[0.5747182983931713,1120.184976359315,447.3194195269595,195.4058178429213,0.44508759420549027,0.3962202062055764, ...

# %%
#@markdown ## Focus on one plot
#@markdown Choose the quantities that you want to plot to have an interactive plot where you can zoom in and out and change colors figure you want to analyse better

x = '%_of_count_above_threshold' #@param ["Energy", "%_of_absolute_sum_of_changes", "%_of_count_above_threshold", "Quantile_75", "Standard_deviation"]
y = '%_of_absolute_sum_of_changes' #@param ["Energy", "%_of_absolute_sum_of_changes", "%_of_count_above_threshold", "Quantile_75", "Standard_deviation"]

#@markdown Choose the colors for the different **treatments**
color_Curare = 'green' #@param ['blue', 'red', 'orange', 'green', 'pink']
color_None = 'blue' #@param ['blue', 'red', 'orange', 'green', 'pink']
color_Other = 'blue' #@param ['blue', 'red', 'orange', 'green', 'pink']
 
#@markdown Choose the marker for the different **phenotypes**
marker_Disease = 'square' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_Recovery = 'cross' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_Control = 'circle' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_Disease_II = 'diamond' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_size = 6 #@param {type:"slider", min:1, max:10, step:1}              

fig = px.scatter(df_data_final, x=x, y=y, width=1000, height=600,
                 color='Treatment during contraction',
                 color_discrete_map={'Curare': my_colors[color_Curare],
                                      'None': my_colors[color_None],
                                      'Other': my_colors[color_Other]},
                 symbol='Phenotype',
                 hover_name = 'Filename',
                 symbol_sequence = [marker_Disease, marker_Recovery, marker_Control, marker_Disease_II]
                 )
fig.update_traces(marker_size=marker_size)

#@markdown If you want to save the figure, check the following box insert, and choose a name. 
save = True #@param {type:"boolean"}
figure_name = "Plot_1" #@param {type:"string"}
if save:
  if figure_name == '':
    print('Attention! If you want to save the figure, please choose a name, and execute the cell!')
  else:
    fig.write_image(figure_path + figure_name + ".png")
    fig.write_html(figure_path + figure_name + ".html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b3594243-0f1a-4a3f-b634-b2e12f3ceff0" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3594243-0f1a-4a3f-b634-b2e12f3ceff0")) {                    Plotly.newPlot(                        "b3594243-0f1a-4a3f-b634-b2e12f3ceff0",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Treatment during contraction=None<br>Phenotype=Disease<br>%_of_count_above_threshold=%{x}<br>%_of_absolute_sum_of_changes=%{y}<extra></extra>","hovertext":["O1445_2a","O1318_2a","O1443_1b","O1318_1b","O1463_1b","O1318_3a","O1449_1a","O1449_1b","O1301_3a","O1409_1b","P766_1b","P918_1b_recovery_curare","O1463_2b","O1450_1b","O1463_2a","O1449_2a","O1467_2a","O1465_1b","O1469_1a"],"legendgroup":"None, Disease","marker":{"color":"royalblue","symbol":"square","size":6},"mode":"markers","name":"None, Disease","orientation":"v","showlegend":true,"x":[0.019343986543313707,0.07079152731326643,0.00436241610738255,0.003169572107765452,0.0,0.277992277992278,0.005887300252312868,0.15559293523969722,0.0,0.025919732441471572,0.0,0.0,0.11017661900756939,0.0,0.24810765349032798,0.31959629941127,0.00042052144659377626,0.023128679562657697,0.011354079058031959],"xaxis":"x","y":[0.012509082505425661,0.0278762333428385,0.018005362322262755,0.016722782413960337,0.0079353096547564,0.11746151408763988,0.01300607356062371,0.047164663655573286,0.008405820862434658,0.013826179391708873,0.007585957045765802,0.004265708265420007,0.027731122117990004,0.01144267350463393,0.03453628612261325,0.07802852880825784,0.015662574421803282,0.019920644557116028,0.019994211127259166],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Treatment during contraction=None<br>Phenotype=Control<br>%_of_count_above_threshold=%{x}<br>%_of_absolute_sum_of_changes=%{y}<extra></extra>","hovertext":["O1319_1a","O1319_3a","O1319_2a","O1448_2a"],"legendgroup":"None, Control","marker":{"color":"royalblue","symbol":"cross","size":6},"mode":"markers","name":"None, Control","orientation":"v","showlegend":true,"x":[0.2996098104793757,0.0,0.30211817168338906,0.0],"xaxis":"x","y":[0.062015734850354706,0.00925065539185466,0.06722596076012338,0.015259049572331857],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Treatment during contraction=None<br>Phenotype=Recovery<br>%_of_count_above_threshold=%{x}<br>%_of_absolute_sum_of_changes=%{y}<extra></extra>","hovertext":["O1464_1a","O1468_1b","O1466_2a","O1464_2a","O1464_1b","O1468_1c"],"legendgroup":"None, Recovery","marker":{"color":"royalblue","symbol":"circle","size":6},"mode":"markers","name":"None, Recovery","orientation":"v","showlegend":true,"x":[0.4377628259041211,0.5172413793103449,0.10428931875525652,0.2409587888982338,0.26238286479250333,0.30908326324642554],"xaxis":"x","y":[0.09643089044340399,0.49845647844626007,0.03585562836991502,0.03219123294071963,0.033318200931988846,0.3903050593557886],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Treatment during contraction=Other<br>Phenotype=Control<br>%_of_count_above_threshold=%{x}<br>%_of_absolute_sum_of_changes=%{y}<extra></extra>","hovertext":["p1229_d50_1a","O4979_1a","O4979_1b","O4979_1c","p1228_d50_1a","p1228_d50_1c","O4980_1b","p1229_d50_2c","p1229_d50_2b","O4980_1a","O4980_3c","O4980_3b","O4980_3a","O4980_2a","O4980_2b","p1229_d50_1c","p1229_d50_1b","O4980_2c","O4979_3b","O4979_3a","O4979_2a","p1228_d50_2b","O4979_2c","O4979_2b","p1228_d50_2a"],"legendgroup":"Other, Control","marker":{"color":"royalblue","symbol":"cross","size":6},"mode":"markers","name":"Other, Control","orientation":"v","showlegend":true,"x":[0.022611464968152868,0.6502557544757033,0.5020780051150895,0.17055626598465473,0.007484076433121019,0.0,0.217391 ...

# %% [markdown]
# ---

# %% [markdown]
# ## Extra

# %%
#@markdown ### Focus on the comparison between the control populations: 'None, Control' vs 'Curare'.

#@markdown In this section we focused only on the controls to explore these populations.

#@markdown We consider all the None, Control. You can select which phenotype you want to include for the Curare ones.


df_controls = df_data_final.loc[(df_data_final['Phenotype'] == 'Control') & (df_data_final['Treatment during contraction'] == 'None')]
# df_controls

include_curare_control = False #@param{type:'boolean'}
if include_curare_control:
  df_curare = df_data_final.loc[(df_data_final['Treatment during contraction'] == 'Curare') & (df_data_final['Phenotype'] == 'Control')]
  df_controls = df_controls.append(df_curare, ignore_index=True)

include_curare_disease = False #@param{type:'boolean'}
if include_curare_disease:
  df_curare_disease = df_data_final.loc[(df_data_final['Treatment during contraction'] == 'Curare') & (df_data_final['Phenotype'] == 'Disease')]
  df_controls = df_controls.append(df_curare_disease, ignore_index=True)
include_curare_disease_II = False #@param{type:'boolean'}
if include_curare_disease_II:
  df_curare_disease_II = df_data_final.loc[(df_data_final['Treatment during contraction'] == 'Curare') & (df_data_final['Phenotype'] == 'Disease II')]
  # df_curare = df_curare.append(df_curare_disease_II, ignore_index=True)
  df_controls = df_controls.append(df_curare_disease_II, ignore_index=True)

#@markdown Choose if you want to include also the 'Other, Control' in the analysis chechink the last box.
include_other_control = True #@param{type:'boolean'}

if include_other_control:
  df_other_control = df_data_final.loc[(df_data_final['Treatment during contraction'] == 'Other') & (df_data_final['Phenotype'] == 'Control')]
  df_controls = df_controls.append(df_other_control, ignore_index=True)

#@markdown Run the cell to see the table with the selected data. In next cell you can visualize and save the boxplots.
# df3 = df_controls.append(df_curare, ignore_index=True)
# df3
df_controls
# Out:
#         Filename       Energy      Mean  %_of_count_above_threshold  \
# 0       O1319_1a    70.826850  0.025057                    0.299610
# 3                0.495374              P472B        H1+RI   Control
# 4                0.507325              P1229      H1 (VF)   Control
# 5                0.717711              P1263     H1 (LDN)   Control
# 6                0.582001              P1263     H1 (LDN)   Control
# 7                0.405531              P1263     H1 (LDN)   Control
# 8                0.477866              P1228           H1   Control
# 9                0.552707              P1228           H1   Control
# 10               0.490729              P1264  H1 (LDN+VF)   Control
# 11               0.484815              P1229      H1 (VF)   Control
# 12               0.430147              P1229      H1 (VF)   Control
# 13               0.506234              P1264  H1 (LDN+VF)   Control
# 14               0.501279              P1264  H1 (LDN+VF)   Control
# 15               0.420396              P1264  H1 (LDN+VF)   Control
# 16               0.497922              P1264  H1 (LDN+VF)   Control
# 17               0.252398              P1264  H1 (LDN+VF)   Control
# 18               0.557385              P1264  H1 (LDN+VF)   Control
# 19               0.671656              P1229      H1 (VF)   Control
# 20               0.338057              P1229      H1 (VF)   Control
# 21               0.392104              P1264  H1 (LDN+VF)   Control
# 22               0.475863              P1263     H1 (LDN)   Control
# 23               0.473465              P1263     H1 (LDN)   Control
# 24               0.440697              P1263     H1 (LDN)   Control
# 25               0.496019              P1228           H1   Control
# 26               0.512948              P1263     H1 (LDN)   Control
# 27               0.454284              P1263     H1 (LDN)   Control
# 28               0.485669              P1228           H1   Control
#
#    Treatment during contraction   Day USER User classification       Sent  \
# 0                          None  60.0  AGP  Strong contraction 2022-05-10
# 1                          None  60.0  AGP      No contraction 2022-05-16
# 2                          None  60.0  AGP         Contraction 2022-12-05
# 3                          None  50.0  AGP         Contraction 2022-12-05
# 4                         Other  50.0   CB                 NaN 2022-12-05
# 5                         Other  50.0   CB                 NaN 2022-12-05
# 6                         Other  50.0   CB                 NaN 2022-12-05
# 7                         Other  50.0   CB                 NaN 2022-12-05
# 8                         Other  50.0   CB                 NaN 2022-12-05
# 9                         Other  50.0   CB                 NaN 2022-12-05
# 10                        Other  50.0   CB                 NaN 2022-12-05
# 11                        Other  50.0   CB                 NaN 2022-12-05
# 12                        Other  50.0   CB                 NaN 2022-12-05
# 13                        Other  50.0   CB                 NaN 2022-12-05
# 14                        Other  50.0   CB                 NaN 2022-12-05
# 15                        Other  50.0   CB                 NaN 2022-12-05
# 16                        Other  50.0   CB                 NaN 2022-12-05
# 17                        Other  50.0   CB                 NaN 2022-12-05
# 18                        Other  50.0   CB                 NaN 2022-12-05
# 19                        Other  50.0   CB                 NaN 2022-12-05
# 20                        Other  50.0   CB                 NaN 2022-12-05
# 21                        Other  50.0   CB                 NaN 2022-12-05
# 22                        Other  50.0   CB                 NaN 2022-12-05
# 23                        Other  50.0   CB                 NaN 2022-12-05
# 24                        Other  50.0   CB                 NaN 2022-12-05
# 25                        Other  50.0   CB                 NaN 2022-12-05
# 26                        Other  50.0   CB                 NaN 2022-12-05
# 27                        Other  50.0   CB                 NaN 2022-12-05
# 28                        Other  50.0   CB                 NaN 2022-12-05
#
#    Comments Threshold
# 0       NaN   default
# 1       NaN   default
# 2       NaN   default
# 3       NaN   default
# 4     O4883   default
# 5       NaN      0.72
# 6       NaN      0.65
# 7       NaN   default
# 8     O4882   default
# 9     O4882   default
# 10      NaN   default
# 11    O4883   default
# 12    O4883   default
# 13      NaN   default
# 14      NaN   default
# 15      NaN   default
# 16      NaN   default
# 17      NaN   default
# 18      NaN   default
# 19    O4883   default
# 20    O4883   default
# 21      NaN   default
# 22      NaN   default
# 23      NaN   default
# 24      NaN   default
# 25    O4882   default
# 26      NaN   default
# 27      NaN   default
# 28    O4882   default

# %%
#@markdown ### Boxplot according to the 'Treatment during contraction'
fig_uni_variate = make_subplots(rows=2, cols=3)
ax_list = [[1, 1], [1, 2], [1, 3], [2, 1], [2, 2], [2, 3]]
ind = 0

# x_boxplot = 'Treatment during contraction' #@param ['Treatment during contraction', 'Phenotype']

x_boxplot = 'Treatment during contraction' 
for ax, col in zip(ax_list, list(df_controls.columns)[1:7]):
    fig_ = px.box(df_controls, x=x_boxplot, y=col, color=x_boxplot)# , points="outliers") # Options: None, all, ouliers, suspectedoutliers")
    for trace in fig_["data"]:
        trace.legendgroup = trace.name
        fig_uni_variate.add_trace(trace, row=ax[0], col=ax[1])
        if ind != 0:
            fig_uni_variate.data[-1].showlegend = False

    if col == 'Energy':
        units = 'Normalized Energy [\u03BCm^2 / s]'
    elif col in ['Standard_deviation', 'Mean', 'Quantile_75']:
        units = col + ' [\u03BCm]'
    else:
        units = col
    fig_uni_variate.update_layout(height=800, width=1500)
    fig_uni_variate.update_xaxes(title_text=x_boxplot, row=ax[0], col=ax[1])
    fig_uni_variate.update_yaxes(title_text=units, row=ax[0], col=ax[1])
    ind += 1

#@markdown If you want to save the figure, check the following box insert and choose a name. 
save = False #@param {type:"boolean"}
figure_name = "" #@param {type:"string"}
if save:
  if figure_name == '':
    print('Attention! If you want to save the figure, please choose a name, and execute the cell!')
  else:
    fig_uni_variate.write_image(figure_path + figure_name + ".png")
    fig_uni_variate.write_html(figure_path + figure_name + ".html")
fig_uni_variate.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a5a7135e-11e3-4b2a-adc8-0d58776de8a0" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5a7135e-11e3-4b2a-adc8-0d58776de8a0")) {                    Plotly.newPlot(                        "a5a7135e-11e3-4b2a-adc8-0d58776de8a0",                        [{"alignmentgroup":"True","hovertemplate":"Treatment during contraction=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"#636efa"},"name":"None","notched":false,"offsetgroup":"None","orientation":"v","showlegend":true,"x":["None","None","None","None"],"x0":" ","xaxis":"x","y":[70.82685036723316,0.09104614474482578,167.0533566183178,0.13330002699948265],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Treatment during contraction=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Other","marker":{"color":"#EF553B"},"name":"Other","notched":false,"offsetgroup":"Other","orientation":"v","showlegend":true,"x":["Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other"],"x0":" ","xaxis":"x","y":[0.574718298393178,1120.1849763593132,447.3194195269591,195.4058178429213,0.44508759420549016,0.3962202062055761,8.378148450908217,85.09533032174133,116.22788319150658,0.3795672586136424,124.1782194620732,0.3403602472147676,0.32661926008639003,771.8045734801485,0.560136628242399,62.987497909394214,0.392591573878306,229.91066371519332,0.17836333844422084,1.0039838862013974,0.8254208337574587,0.5142972053123557,1.3951148739045838,0.5145648119614923,0.5692668507950804],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Treatment during contraction=%{x}<br>Mean=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"#636efa"},"name":"None","notched":false,"offsetgroup":"None","orientation":"v","showlegend":false,"x":["None","None","None","None"],"x0":" ","xaxis":"x2","y":[0.025057136981643864,0.00034039956099891737,-0.0057257989809337976,4.409385720468428e-05],"y0":" ","yaxis":"y2","type":"box"},{"alignmentgroup":"True","hovertemplate":"Treatment during contraction=%{x}<br>Mean=%{y}<extra></extra>","legendgroup":"Other","marker":{"color":"#EF553B"},"name":"Other","notched":false,"offsetgroup":"Other","orientation":"v","showlegend":false,"x":["Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other"],"x0":" ","xaxis":"x2","y":[-0.001587714251988262,-0.013960971924013115,-0.006256253240658881,0.00015439141044940507,-0.001152699525563917,-0.00043853454776188807,-0.00011466379528160889,0.007062492132084397,-0.0010825694593374737,-0.000891832596054396,-0.005326675928946697,-0.001014808297515938,-0.0002805208124624117,0.04166130131592344,0.0002215785673281984,-0.002376054765755701,-0.0003644289690812129,0.020687595776212195,0.0007238907192495465,-0.0007141405612661157,0.0015317814742546144,0.00038000537374927165,-0.0019455753538906515,0.0001070239499791707,-0.0018745181519041238],"y0":" ","yaxis":"y2","type":"box"},{"alignmentgroup":"True","hovertemplate":"Treatment during contraction=%{x}<br>%_of_count_above_threshold=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"#636efa"},"name":"None","notched":false,"offsetgroup":"None","orientation":"v","showlegend":false,"x":["None","None","None","None"],"x0":" ","xaxis":"x3","y":[0.2996098104793757,0.0,0.30211817168338906,0.0],"y0":" ","yaxis":"y3","type":"box"},{"alignmentgroup":"True","hovertemplate":"Treatment during contraction=%{x}<br>%_of_count_above_threshold=%{y}<extra></extra>","legendgro ...

# %%
#@markdown # No Curare
#@markdown In this section we focus on all the data excluding 'Curare'
df_no_curare = df_data_final.loc[df_data_final['Treatment during contraction'] != 'Curare']
# df_no_curare = df_data_final.loc[df_data_final['Treatment during contraction'] != 'Other']

df_no_curare
# Out:
#                    Filename       Energy      Mean  \
# 0                  O1445_2a     0.494167  0.001553
# 1                  O1319_1a    70.826850  0.025057
# 2                  O1318_2a     1.313557  0.001413
# 3                  O1464_1a   208.187278  0.035326
# 4                  O1468_1b  1648.618763 -0.007170
# 5                  O1466_2a     2.281303 -0.007108
# 6                  O1443_1b     0.802573  0.000358
# 7                  O1319_3a     0.091046  0.000340
# 8                  O1464_2a    10.135316  0.001734
# 9                  O1318_1b     0.359386 -0.000743
# 10                 O1463_1b     0.139914 -0.000366
# 11                 O1318_3a   187.547294  0.045948
# 12                 O1449_1a     0.382861 -0.001477
# 13             p1229_d50_1a     0.574718 -0.001588
# 14                 O1449_1b    64.623116  0.004853
# 15                 O4979_1a  1120.184976 -0.013961
# 16                 O1319_2a   167.053357 -0.005726
# 17                 O4979_1b   447.319420 -0.006256
# 46            0.181373               0.420396              P1264  H1 (LDN+VF)
# 47            0.176923               0.497922              P1264  H1 (LDN+VF)
# 48            8.652004               0.252398              P1264  H1 (LDN+VF)
# 49            0.293926               0.500841              P483A  SMAE1C4-DOX
# 50            0.233017               0.557385              P1264  H1 (LDN+VF)
# 51            2.452121               0.671656              P1229      H1 (VF)
# 52            0.113706               0.495374              P472B        H1+RI
# 53            0.208629               0.479815               P488  SMAE1C4-DOX
# 54            0.193760               0.338057              P1229      H1 (VF)
# 55            4.722373               0.392104              P1264  H1 (LDN+VF)
# 57            0.125368               0.475863              P1263     H1 (LDN)
# 58            0.312052               0.473465              P1263     H1 (LDN)
# 60            0.282946               0.440697              P1263     H1 (LDN)
# 62            0.222649               0.496019              P1228           H1
# 63            0.364986               0.512948              P1263     H1 (LDN)
# 64            0.220994               0.454284              P1263     H1 (LDN)
# 65            0.229818               0.485669              P1228           H1
#
#    Phenotype Treatment during contraction   Day USER User classification  \
# 0    Disease                         None  60.0  AGP      No contraction
# 1    Control                         None  60.0  AGP  Strong contraction
# 2    Disease                         None  60.0  AGP    Weak contraction
# 3   Recovery                         None  50.0  AGP  Strong contraction
# 4   Recovery                         None  50.0  AGP  Strong contraction
# 5   Recovery                         None  50.0  AGP  Strong contraction
# 6    Disease                         None  40.0  AGP    Weak contraction
# 7    Control                         None  60.0  AGP      No contraction
# 8   Recovery                         None  50.0  AGP  Strong contraction
# 9    Disease                         None  60.0  AGP    Weak contraction
# 10   Disease                         None  50.0  AGP      No contraction
# 11   Disease                         None  60.0  AGP    Weak contraction
# 12   Disease                         None  50.0  AGP    Weak contraction
# 13   Control                        Other  50.0   CB                 NaN
# 14   Disease                         None  50.0  AGP         Contraction
# 15   Control                        Other  50.0   CB                 NaN
# 16   Control                         None  60.0  AGP         Contraction
# 17   Control                        Other  50.0   CB                 NaN
# 18   Disease                         None  50.0  AGP    Weak contraction
# 19   Disease                         None  40.0  AGP      No contraction
# 23   Disease                         None  60.0  AGP      No contraction
# 24   Disease                         None  50.0  AGP      No contraction
# 31   Disease                         None  50.0  AGP    Weak contraction
# 32   Control                        Other  50.0   CB                 NaN
# 33   Control                        Other  50.0   CB                 NaN
# 34   Disease                         None  50.0  AGP         Contraction
# 35   Control                        Other  50.0   CB                 NaN
# 36   Disease                         None  50.0  AGP    Weak contraction
# 37   Disease                         None  50.0  AGP         Contraction
# 38  Recovery                         None  50.0  AGP         Contraction
# 39  Recovery                         None  50.0  AGP         Contraction
# 40   Control                        Other  50.0   CB                 NaN
# 41   Control                        Other  50.0   CB                 NaN
# 42   Control                        Other  50.0   CB                 NaN
# 43   Control                        Other  50.0   CB                 NaN
# 44   Disease                         None  50.0  AGP    Weak contraction
# 45   Control                        Other  50.0   CB                 NaN
# 46   Control                        Other  50.0   CB                 NaN
# 47   Control                        Other  50.0   CB                 NaN
# 48   Control                        Other  50.0   CB                 NaN
# 49   Disease                         None  50.0  AGP    Weak contraction
# 50   Control                        Other  50.0   CB                 NaN
# 51   Control                        Other  50.0   CB                 NaN
# 52   Control                         None  50.0  AGP         Contraction
# 53   Disease                         None  50.0  AGP    Weak contraction
# 54   Control                        Other  50.0   CB                 NaN
# 55   Control                        Other  50.0   CB                 NaN
# 57   Control                        Other  50.0   CB                 NaN
# 58   Control                        Other  50.0   CB                 NaN
# 60   Control                        Other  50.0   CB                 NaN
# 62   Control                        Other  50.0   CB                 NaN
# 63   Control                        Other  50.0   CB                 NaN
# 64   Control                        Other  50.0   CB                 NaN
# 65   Control                        Other  50.0   CB                 NaN
#
#          Sent Comments Threshold
# 0  2022-05-16      NaN   default
# 1  2022-05-10      NaN   default
# 2  2022-05-10      NaN   default
# 3  2022-05-10      NaN   default
# 4  2022-05-10      NaN   default
# 5  2022-05-10      NaN   default
# 6  2022-05-10      NaN   default
# 7  2022-05-16      NaN   default
# 8  2022-05-10      NaN   default
# 9  2022-05-10      NaN   default
# 10 2022-05-16      NaN   default
# 11 2022-05-10      NaN   default
# 12 2022-12-05      NaN   default
# 13 2022-12-05    O4883   default
# 14 2022-12-05      NaN   default
# 15 2022-12-05      NaN      0.72
# 16 2022-12-05      NaN   default
# 17 2022-12-05      NaN      0.65
# 18 2022-05-10      NaN   default
# 19 2022-09-02      NaN   default
# 23 2022-09-02    O3062   default
# 24 2022-09-02    O3779   default
# 31 2022-12-05      NaN   default
# 32 2022-12-05      NaN   default
# 33 2022-12-05    O4882   default
# 34 2022-12-05      NaN   default
# 35 2022-12-05    O4882   default
# 36 2022-12-05      NaN   default
# 37 2022-12-05      NaN   default
# 38 2022-12-05      NaN   default
# 39 2022-12-05      NaN   default
# 40 2022-12-05      NaN   default
# 41 2022-12-05    O4883   default
# 42 2022-12-05    O4883   default
# 43 2022-12-05      NaN   default
# 44 2022-12-05      NaN   default
# 45 2022-12-05      NaN   default
# 46 2022-12-05      NaN   default
# 47 2022-12-05      NaN   default
# 48 2022-12-05      NaN   default
# 49 2022-12-05      NaN   default
# 50 2022-12-05      NaN   default
# 51 2022-12-05    O4883   default
# 52 2022-12-05      NaN   default
# 53 2022-12-05      NaN   default
# 54 2022-12-05    O4883   default
# 55 2022-12-05      NaN   default
# 57 2022-12-05      NaN   default
# 58 2022-12-05      NaN   default
# 60 2022-12-05      NaN   default
# 62 2022-12-05    O4882   default
# 63 2022-12-05      NaN   default
# 64 2022-12-05      NaN   default
# 65 2022-12-05    O4882   default

# %%
#@markdown ## Uni-variate subplot with no Curare
fig_uni_variate = make_subplots(rows=2, cols=3)
ax_list = [[1, 1], [1, 2], [1, 3], [2, 1], [2, 2], [2, 3]]
ind = 0

x_boxplot = 'Phenotype'

for ax, col in zip(ax_list, list(df_data_final.columns)[1:7]):
    fig_ = px.box(df_no_curare, x=x_boxplot, y=col, color=x_boxplot)# , points="outliers") # Options: None, all, ouliers, suspectedoutliers")
    for trace in fig_["data"]:
        trace.legendgroup = trace.name
        fig_uni_variate.add_trace(trace, row=ax[0], col=ax[1])
        if ind != 0:
            fig_uni_variate.data[-1].showlegend = False

    if col == 'Energy':
        units = 'Normalized Energy [\u03BCm^2 / s]'
    elif col in ['Standard_deviation', 'Mean', 'Quantile_75']:
        units = col + ' [\u03BCm]'
    else:
        units = col
    fig_uni_variate.update_layout(height=800, width=1500)
    fig_uni_variate.update_xaxes(title_text=x_boxplot, row=ax[0], col=ax[1])
    fig_uni_variate.update_yaxes(title_text=units, row=ax[0], col=ax[1])
    ind += 1

fig_uni_variate.show()
fig_uni_variate.write_html(figure_path + "Univariate - No Curare" + ".html")
fig_uni_variate.write_image(figure_path + "Univariate - No Curare " + ".png", format='png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="56c11040-6142-4df3-b911-048a8a008ffb" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56c11040-6142-4df3-b911-048a8a008ffb")) {                    Plotly.newPlot(                        "56c11040-6142-4df3-b911-048a8a008ffb",                        [{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Disease","marker":{"color":"#636efa"},"name":"Disease","notched":false,"offsetgroup":"Disease","orientation":"v","showlegend":true,"x":["Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease"],"x0":" ","xaxis":"x","y":[0.4941671058983653,1.313557410872148,0.802573020752049,0.3593863389734834,0.13991439466937397,187.5472942223901,0.38286058233088827,64.6231155348736,0.10888701342483728,0.43354780188984665,0.19404420953690565,0.06573115883776608,2.782979007560309,0.47124508708802126,5.482655939911465,127.1505598686195,0.288414740078688,0.89067984778527,0.44935079806623046],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Control","marker":{"color":"#EF553B"},"name":"Control","notched":false,"offsetgroup":"Control","orientation":"v","showlegend":true,"x":["Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control","Control"],"x0":" ","xaxis":"x","y":[70.82685036723316,0.09104614474482578,0.574718298393178,1120.1849763593132,167.0533566183178,447.3194195269591,195.4058178429213,0.44508759420549016,0.3962202062055761,8.378148450908217,85.09533032174133,116.22788319150658,0.3795672586136424,124.1782194620732,0.3403602472147676,0.32661926008639003,771.8045734801485,0.560136628242399,62.987497909394214,0.13330002699948265,0.392591573878306,229.91066371519332,0.17836333844422084,1.0039838862013974,0.8254208337574587,0.5142972053123557,1.3951148739045838,0.5145648119614923,0.5692668507950804],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Recovery","marker":{"color":"#00cc96"},"name":"Recovery","notched":false,"offsetgroup":"Recovery","orientation":"v","showlegend":true,"x":["Recovery","Recovery","Recovery","Recovery","Recovery","Recovery"],"x0":" ","xaxis":"x","y":[208.187278161135,1648.6187629803612,2.281302771437745,10.135315834092907,6.569781298247705,1578.8955641966322],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Mean=%{y}<extra></extra>","legendgroup":"Disease","marker":{"color":"#636efa"},"name":"Disease","notched":false,"offsetgroup":"Disease","orientation":"v","showlegend":false,"x":["Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease","Disease"],"x0":" ","xaxis":"x2","y":[0.0015532942408867496,0.0014129855602832875,0.0003576143784080366,-0.0007428683703790457,-0.0003663206554329104,0.04594808476449938,-0.0014766219865843565,0.004853471378074424,-0.000802079481918541,0.0009443632199893784,0.0010781717325713481,0.0007446884153411921,0.0030754831326965915,0.0029223585285035173,0.009191803763454926,-0.01213908752986481,-0.0004363441741951569,-0.0016352098957066268,-0.0012170304240744167],"y0":" ","yaxis":"y2","type":"box"},{"alignmentgroup":"True","hovertemplate":"Phenotype=%{x}<br>Mean=%{y}<e ...

# %%
df_data_final
# Out:
#            Filename       Energy      Mean  %_of_count_above_threshold  \
# 0          O1445_2a     0.494167  0.001553                    0.019344
# 1          O1319_1a    70.826850  0.025057                    0.299610
# 2          O1318_2a     1.313557  0.001413                    0.070792
# 3          O1464_1a   208.187278  0.035326                    0.437763
# 4          O1468_1b  1648.618763 -0.007170                    0.517241
# ..              ...          ...       ...                         ...
# 62     p1228_d50_2b     0.514297  0.000380                    0.016083
# 63         O4979_2c     1.395115 -0.001946                    0.099425
# 64         O4979_2b     0.514565  0.000107                    0.033088
# 65     p1228_d50_2a     0.569267 -0.001875                    0.029777
# 66  O4980_2c-curare     0.506616  0.001049                    0.014866
#
#     %_of_absolute_sum_of_changes  Quantile_75  Standard_deviation  \
# 0                       0.012509     0.091639            0.218823
# 1                       0.062016     0.623074            2.617394
# 2                       0.027876     0.224592            0.356947
# 3                       0.096431     1.503946            4.493569
# 4                       0.498456     7.451611           12.645776
# ..                           ...          ...                 ...
# 62                      0.007837     0.154671            0.222649
# 63                      0.012318     0.237232            0.364986
# 64                      0.007377     0.140999            0.220994
# 65                      0.006536     0.135267            0.229818
# 66                      0.009050     0.135236            0.221644
#
#     %_of_count_above_mean Experiment (plate)    Cell line Phenotype  \
# 0                0.542893               P426      SMAE1C4   Disease
# 1                0.469621               P427           H1   Control
# 2                0.491639               P426      SMAE1C4   Disease
# 3                0.519765               P482  SMAE1C4+DOX  Recovery
# 4                0.533221               P487  SMAE1C4+DOX  Recovery
# ..                    ...                ...          ...       ...
# 62               0.496019              P1228           H1   Control
# 63               0.512948              P1263     H1 (LDN)   Control
# 64               0.454284              P1263     H1 (LDN)   Control
# 65               0.485669              P1228           H1   Control
# 66               0.494885              P1264  H1 (LDN+VF)   Control
#
#    Treatment during contraction   Day USER User classification       Sent  \
# 0                          None  60.0  AGP      No contraction 2022-05-16
# 1                          None  60.0  AGP  Strong contraction 2022-05-10
# 2                          None  60.0  AGP    Weak contraction 2022-05-10
# 3                          None  50.0  AGP  Strong contraction 2022-05-10
# 4                          None  50.0  AGP  Strong contraction 2022-05-10
# ..                          ...   ...  ...                 ...        ...
# 62                        Other  50.0   CB                 NaN 2022-12-05
# 63                        Other  50.0   CB                 NaN 2022-12-05
# 64                        Other  50.0   CB                 NaN 2022-12-05
# 65                        Other  50.0   CB                 NaN 2022-12-05
# 66                       Curare  50.0   CB                 NaN 2022-12-05
#
#    Comments Threshold
# 0       NaN   default
# 1       NaN   default
# 2       NaN   default
# 3       NaN   default
# 4       NaN   default
# ..      ...       ...
# 62    O4882   default
# 63      NaN   default
# 64      NaN   default
# 65    O4882   default
# 66      NaN      0.69
#
# [67 rows x 18 columns]

# %%
df_last = df_data_final.copy()
df_last['class'] = 'Curare'
df_last['class'].loc[df_last['Treatment during contraction'] != 'Curare'] = 'Non-curare'
df_last
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Filename       Energy      Mean  %_of_count_above_threshold  \
# 0          O1445_2a     0.494167  0.001553                    0.019344
# 1          O1319_1a    70.826850  0.025057                    0.299610
# 2          O1318_2a     1.313557  0.001413                    0.070792
# 3          O1464_1a   208.187278  0.035326                    0.437763
# 4          O1468_1b  1648.618763 -0.007170                    0.517241
# ..              ...          ...       ...                         ...
# 62     p1228_d50_2b     0.514297  0.000380                    0.016083
# 63         O4979_2c     1.395115 -0.001946                    0.099425
# 64         O4979_2b     0.514565  0.000107                    0.033088
# 65     p1228_d50_2a     0.569267 -0.001875                    0.029777
# 66  O4980_2c-curare     0.506616  0.001049                    0.014866
#
#     %_of_absolute_sum_of_changes  Quantile_75  Standard_deviation  \
# 0                       0.012509     0.091639            0.218823
# 1                       0.062016     0.623074            2.617394
# 2                       0.027876     0.224592            0.356947
# 3                       0.096431     1.503946            4.493569
# 4                       0.498456     7.451611           12.645776
# ..                           ...          ...                 ...
# 62                      0.007837     0.154671            0.222649
# 63                      0.012318     0.237232            0.364986
# 64                      0.007377     0.140999            0.220994
# 65                      0.006536     0.135267            0.229818
# 66                      0.009050     0.135236            0.221644
#
#     %_of_count_above_mean Experiment (plate)    Cell line Phenotype  \
# 0                0.542893               P426      SMAE1C4   Disease
# 1                0.469621               P427           H1   Control
# 2                0.491639               P426      SMAE1C4   Disease
# 3                0.519765               P482  SMAE1C4+DOX  Recovery
# 4                0.533221               P487  SMAE1C4+DOX  Recovery
# ..                    ...                ...          ...       ...
# 62               0.496019              P1228           H1   Control
# 63               0.512948              P1263     H1 (LDN)   Control
# 64               0.454284              P1263     H1 (LDN)   Control
# 65               0.485669              P1228           H1   Control
# 66               0.494885              P1264  H1 (LDN+VF)   Control
#
#    Treatment during contraction   Day USER User classification       Sent  \
# 0                          None  60.0  AGP      No contraction 2022-05-16
# 1                          None  60.0  AGP  Strong contraction 2022-05-10
# 2                          None  60.0  AGP    Weak contraction 2022-05-10
# 3                          None  50.0  AGP  Strong contraction 2022-05-10
# 4                          None  50.0  AGP  Strong contraction 2022-05-10
# ..                          ...   ...  ...                 ...        ...
# 62                        Other  50.0   CB                 NaN 2022-12-05
# 63                        Other  50.0   CB                 NaN 2022-12-05
# 64                        Other  50.0   CB                 NaN 2022-12-05
# 65                        Other  50.0   CB                 NaN 2022-12-05
# 66                       Curare  50.0   CB                 NaN 2022-12-05
#
#    Comments Threshold       class
# 0       NaN   default  Non-curare
# 1       NaN   default  Non-curare
# 2       NaN   default  Non-curare
# 3       NaN   default  Non-curare
# 4       NaN   default  Non-curare
# ..      ...       ...         ...
# 62    O4882   default  Non-curare
# 63      NaN   default  Non-curare
# 64      NaN   default  Non-curare
# 65    O4882   default  Non-curare
# 66      NaN      0.69      Curare
#
# [67 rows x 19 columns]

# %%
#@markdown ## Uni-variate subplot with Curare vs Rest of the World
fig_uni_variate = make_subplots(rows=2, cols=3)
ax_list = [[1, 1], [1, 2], [1, 3], [2, 1], [2, 2], [2, 3]]
ind = 0

x_boxplot = 'class'

for ax, col in zip(ax_list, list(df_last.columns)[1:7]):
    fig_ = px.box(df_last, x=x_boxplot, y=col, color=x_boxplot)# , points="outliers") # Options: None, all, ouliers, suspectedoutliers")
    for trace in fig_["data"]:
        trace.legendgroup = trace.name
        fig_uni_variate.add_trace(trace, row=ax[0], col=ax[1])
        if ind != 0:
            fig_uni_variate.data[-1].showlegend = False

    if col == 'Energy':
        units = 'Normalized Energy [\u03BCm^2 / s]'
    elif col in ['Standard_deviation', 'Mean', 'Quantile_75']:
        units = col + ' [\u03BCm]'
    else:
        units = col
    fig_uni_variate.update_layout(height=800, width=1500)
    fig_uni_variate.update_xaxes(title_text=x_boxplot, row=ax[0], col=ax[1])
    fig_uni_variate.update_yaxes(title_text=units, row=ax[0], col=ax[1])
    ind += 1

fig_uni_variate.show()
# fig_uni_variate.write_html(figure_path + "Univariate - Curare - vs - Rest" + ".html")
# fig_uni_variate.write_image(figure_path + "Univariate - Curare - vs - Rest " + ".png", format='png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5934306f-2c9f-43a4-b2fe-80825a12027c" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5934306f-2c9f-43a4-b2fe-80825a12027c")) {                    Plotly.newPlot(                        "5934306f-2c9f-43a4-b2fe-80825a12027c",                        [{"alignmentgroup":"True","hovertemplate":"class=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Non-curare","marker":{"color":"#636efa"},"name":"Non-curare","notched":false,"offsetgroup":"Non-curare","orientation":"v","showlegend":true,"x":["Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare"],"x0":" ","xaxis":"x","y":[0.4941671058983653,70.82685036723316,1.313557410872148,208.187278161135,1648.6187629803612,2.281302771437745,0.802573020752049,0.09104614474482578,10.135315834092907,0.3593863389734834,0.13991439466937397,187.5472942223901,0.38286058233088827,0.574718298393178,64.6231155348736,1120.1849763593132,167.0533566183178,447.3194195269591,0.10888701342483728,0.43354780188984665,0.19404420953690565,0.06573115883776608,2.782979007560309,195.4058178429213,0.44508759420549016,0.47124508708802126,0.3962202062055761,5.482655939911465,127.1505598686195,6.569781298247705,1578.8955641966322,8.378148450908217,85.09533032174133,116.22788319150658,0.3795672586136424,0.288414740078688,124.1782194620732,0.3403602472147676,0.32661926008639003,771.8045734801485,0.89067984778527,0.560136628242399,62.987497909394214,0.13330002699948265,0.44935079806623046,0.392591573878306,229.91066371519332,0.17836333844422084,1.0039838862013974,0.8254208337574587,0.5142972053123557,1.3951148739045838,0.5145648119614923,0.5692668507950804],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"class=%{x}<br>Energy=%{y}<extra></extra>","legendgroup":"Curare","marker":{"color":"#EF553B"},"name":"Curare","notched":false,"offsetgroup":"Curare","orientation":"v","showlegend":true,"x":["Curare","Curare","Curare","Curare","Curare","Curare","Curare","Curare","Curare","Curare","Curare","Curare","Curare"],"x0":" ","xaxis":"x","y":[0.6777122653998175,0.6052206829870797,3.537289152048827,0.16916457414859606,0.7850272920584804,0.1727483816140045,0.6462093438770008,0.08146190554369728,0.44389080869707465,0.6683933401586601,0.50901132773345,1.2800154476229952,0.5066163990511912],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"class=%{x}<br>Mean=%{y}<extra></extra>","legendgroup":"Non-curare","marker":{"color":"#636efa"},"name":"Non-curare","notched":false,"offsetgroup":"Non-curare","orientation":"v","showlegend":false,"x":["Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-curare","Non-cu ...

# %%
#@markdown Choose the colors for the different **treatments**
my_colors = {'blue': 'royalblue',
             'red': 'orangered',
             'orange': 'darkorange',
             'green': 'mediumseagreen',
             'pink': 'orchid'

}
color_Curare = 'red' #@param ['blue', 'red', 'orange', 'green', 'pink']
color_None = 'blue' #@param ['blue', 'red', 'orange', 'green', 'pink']
color_Other = 'orange' #@param ['blue', 'red', 'orange', 'green', 'pink']
 
#@markdown Choose the marker for the different **phenotypes**
marker_Disease = 'square' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_Recovery = 'cross' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_Control = 'circle' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_Disease_II = 'square-open' #@param ['circle', 'diamond', 'cross', 'square', 'circle-open', 'square-open']
marker_size = 6 #@param {type:"slider", min:1, max:10, step:1} 

#@markdown The figure will be automatically saved in the 'figures' folder.

var_plot = [
    ['Energy', '%_of_absolute_sum_of_changes', 1, 1],
    ['Energy', 'Quantile_75', 1, 2],
    ['%_of_count_above_threshold', '%_of_absolute_sum_of_changes', 1, 3],
    ['%_of_absolute_sum_of_changes', 'Quantile_75', 2, 1],
    ['%_of_absolute_sum_of_changes', 'Standard_deviation', 2, 2],
    ['Quantile_75', 'Standard_deviation', 2, 3]
]

fig_final = make_subplots(rows=2, cols=3)

ind = 0
for x, y, r, c in var_plot:
    
    fig_ = px.scatter(df_last, x=x, y=y,
                 color='class',
                 color_discrete_map={'Curare': my_colors[color_Curare],
                                      'None': my_colors[color_None],
                                      'Other': my_colors[color_Other]
                                     },
                 symbol='Phenotype',
                 hover_name = 'Filename',
                 symbol_sequence = [marker_Disease, marker_Recovery, marker_Control, marker_Disease_II]
                 )
    fig_.update_traces(marker_size=marker_size)

    for trace in fig_["data"]:
        trace.legendgroup = trace.name
        fig_final.add_trace(trace, row=r, col=c)
        if ind != 0:
            fig_final.data[-1].showlegend = False
    fig_final.update_layout(height=800, width=1500)
    fig_final.update_xaxes(title_text=x, row=r, col=c)
    fig_final.update_yaxes(title_text=y, row=r, col=c)
    ind += 1

# fig_final.write_html(figure_path + "Bivariate.html")
# fig_final.write_image(figure_path + "Bivariate.png")
fig_final.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4c2ea075-c18e-4856-b57b-f41d38a12936" class="plotly-graph-div" style="height:800px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c2ea075-c18e-4856-b57b-f41d38a12936")) {                    Plotly.newPlot(                        "4c2ea075-c18e-4856-b57b-f41d38a12936",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br